# %%
############ libraries ##################################
import cv2
import os
import numpy as np
import PIL
from scipy import misc
import imageio
from time import sleep
import time
from keras.models import model_from_json
import pandas as pd
import itertools
import keras
from sklearn import metrics
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix
from keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
from keras.models import Sequential
from keras import optimizers
from keras.preprocessing import image
from keras.layers import Dropout, Flatten, Dense
from keras import applications
from keras.utils.np_utils import to_categorical
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
#%matplotlib inline
import math
import datetime
import tensorflow.keras as tf
from keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from keras.layers import BatchNormalization
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, LSTM, merge
from keras import metrics
from keras.losses import categorical_crossentropy
from keras.optimizers import SGD
from keras import layers
from keras.callbacks import EarlyStopping
from keras.optimizers import Adam
#from tensorflow.contrib.keras import losses,optimizers,metrics
#from tensorflow.contrib.keras import layers
from keras import initializers
from sklearn.model_selection import train_test_split
from sklearn.utils.multiclass import unique_labels
from keras.applications import VGG19
from keras.callbacks import ModelCheckpoint
import ipdb
import h5py
from keras.layers import LeakyReLU
from keras.models import load_model
from keras.models import Model
import json
from matplotlib import pyplot as plt
import sys
sys.path
sys.executable
import operator
import queue
import pickle
from tensorflow.keras.utils import Sequence
from keras.layers import Input
# %matplotlib inline
import seaborn as sn
from sklearn.metrics import classification_report
from tensorflow.keras.applications.resnet50 import ResNet50
start = datetime.datetime.now()
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
from sklearn.preprocessing import StandardScaler
from PIL import Image, ImageOps
import numpy as np
from skimage import transform
from sklearn.preprocessing import LabelBinarizer
from keras.layers import concatenate
import glob

# %%
data_path = "Excel_data/input_fusion_paths_rough.csv"
root_dir="WOOD_PLASTIC/IMAGES_dummy"
global n_classes
n_classes=11
rv=[]#### return values object list from rough_data values
label=[]
image_list = []
a=[]
batch_size = 16
densenet121=applications.DenseNet121(include_top=False,weights="imagenet")
datagen = ImageDataGenerator(rescale=1. / 255, horizontal_flip=True)
img_width, img_height = 128, 512



def load_samples(csv_file):
    global train_whole, test_whole, tr_rough_X, ts_rough_X, tr_img_X, ts_img_X 
    global  tr_rough_Y, ts_rough_Y, tr_img_Y, ts_img_Y
    ### use global inside a function to access those variables outside the function
    data = pd.read_csv(csv_file)
    data = data[['RaX','RaY','RqX','RqY','RzX','RzY','Filenames','Class','Labels']]
    training_data, testing_data = train_test_split(data, test_size=0.2, random_state=25)
    train_whole= np.array(training_data)
    test_whole =np.array(testing_data)
    tr_rough_X =train_whole[:,0:6] ## values train
    ts_rough_X =test_whole[:,0:6] ## values test
    tr_img_X   =train_whole[:,6:9]## imgs train, training data
    ts_img_X   =test_whole[:,6:9] ## imgs test, validation data
    train_rough_Y =train_whole[:,7].reshape(-1,1)######## shape is (275,1)
    encoder = OneHotEncoder(sparse=False)
    tr_rough_Y = encoder.fit_transform(train_rough_Y)
    test_rough_Y =test_whole[:,7].reshape(-1,1)
    encoder = OneHotEncoder(sparse=False)
    ts_rough_Y = encoder.fit_transform(test_rough_Y)
    tr_img_Y   =train_whole[:,8] ## train labels
    ts_img_Y   =test_whole[:,8] ## test labels
    file_names = list(data.iloc[:,6])
    # Get the labels present in the second column
    labels = list(data.iloc[:,8])
    samples=[]
    for samp,lab in zip(file_names,labels):
        samples.append([samp,lab])
    return samples

samples = load_samples(data_path)
train_df = pd.DataFrame(tr_img_X) ## convert array to df
train_df.columns=['filename','class','labels'] ## add header to df
#print(train_df)
test_df = pd.DataFrame(ts_img_X) ## convert array to df
test_df.columns=['filename','class','labels'] ## add header filename to df
#print(test_df)


def images():
    
    ##Train#####################################################################################
    generator_train = datagen.flow_from_dataframe(train_df, directory=None, x_col='filename', y_col='class',target_size =(img_width, img_height), batch_size=batch_size, 
                      class_mode = 'categorical', shuffle=False) 
    nb_train_samples = len(train_df)
    print('nb_train_samples', nb_train_samples)
    predict_size_train = int(math.ceil(nb_train_samples / batch_size)) 
    bottleneck_features_train = densenet121.predict_generator(generator_train, predict_size_train) 
    np.save("features_training_densenet121_fusion_seq.npy", bottleneck_features_train)
    print('done training')   

    
    #VALIDATION##################################################################################
    
    generator_val = datagen.flow_from_dataframe(test_df, directory=None, x_col='filename', y_col='class', target_size=(img_width, img_height),batch_size=batch_size, 
                    class_mode='categorical', shuffle=False) 
    print('generator_val is',generator_val)
    nb_validation_samples = len(test_df) 
    predict_size_validation = int(math.ceil(nb_validation_samples / batch_size)) 
    bottleneck_features_validation = densenet121.predict_generator(generator_val, predict_size_validation) 
    np.save("features_validation_densenet121_fusion_seq.npy", bottleneck_features_validation)
    print('validation done')
    
   
    # Training data load ##############################################################################
    load_train = datagen.flow_from_dataframe(train_df, directory=None, x_col='filename', y_col='class', target_size =(img_width, img_height), batch_size=batch_size, 
                      class_mode = 'categorical', shuffle=False) 
    nb_train_samples = len(train_df)
    train_data = np.load("features_training_densenet121_fusion_seq.npy") 
    print ('train_data.shape',train_data.shape)
    train_labels = tr_img_Y  
    train_labels = to_categorical(train_labels, num_classes=n_classes)
    #print('train_labels',train_labels)
    
    # validation data load ##########################################################################################
    load_val = datagen.flow_from_dataframe(test_df, directory=None, x_col='filename', y_col='class', target_size=(img_width, img_height),batch_size=batch_size, 
                    class_mode='categorical', shuffle=False) 
    nb_validation_samples = len(test_df)
    validation_data = np.load("features_validation_densenet121_fusion_seq.npy") 
    validation_labels = ts_img_Y  
    validation_labels = to_categorical(validation_labels, num_classes=n_classes)
    z=[train_data, validation_data, validation_labels, train_labels]
    return z
im=images()  ## stores train_data, validation_data, validation_labels, train_labels

def create_dense(feed):
# define our MLP network
    #global trainRX
    model = Sequential()
    model.add(Dense(64, input_shape=feed, activation='relu', name='fc1')) ### input shape to dense is 1D
    model.add(BatchNormalization())## add after Activation function ####
    model.add(Dense(32, activation='relu', name='fc2'))
    model.add(BatchNormalization())
    return model

def create_vgg(input_shape, cls, optimizer='adam', fine_tune=0):
    ######### Adding own model on top of vgg ##################
    model = Sequential() 
    model.add(Flatten(input_shape=input_shape)) 
    model.add(Dropout(0.5))
    model.add(Dense(100))
    model.add(layers.LeakyReLU(alpha=0.3))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    model.add(Dense(50))
    model.add(layers.LeakyReLU(alpha=0.3))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))##### try 0.7 dropout
    #model.add(Dense(n_classes, activation='softmax'))
    #model.add(Dense(32))
    #model.summary()
    # Group the convolutional base and new fully-connected layers into a Model object.
    return model

#input_dense=[]
train_data=im[0]
val=im[1]
val_label=im[2]
tr_label=im[3]
input_dense=tr_rough_X[0].shape
# Out:
# Found 220 validated image filenames belonging to 11 classes.
# nb_train_samples 220
# done training
# Found 55 validated image filenames belonging to 11 classes.
# generator_val is <tensorflow.python.keras.preprocessing.image.DataFrameIterator object at 0x000001BBB84DB790>
# validation done
# Found 220 validated image filenames belonging to 11 classes.
# train_data.shape (220, 4, 16, 1024)
# Found 55 validated image filenames belonging to 11 classes.

# %%
tr_rough_X_tensor=tf.convert_to_tensor(tr_rough_X, np.float32)
tr_rough_Y_tensor=tf.convert_to_tensor(tr_rough_Y, np.float32)
ts_rough_X_tensor=tf.convert_to_tensor(ts_rough_X, np.float32)
ts_rough_Y_tensor=tf.convert_to_tensor(ts_rough_Y, np.float32)

class_names=['ABS','PA','PC','PP','WOOD1','WOOD2','WOOD3','WOOD4','WOOD5','WOOD6','WOOD7']
mlp = create_dense(input_dense)
cnn = create_vgg(train_data.shape[1:],n_classes)
combinedInput = concatenate([mlp.output, cnn.output])
#model = concatenate([mlp.output, cnn.output])
top= Dense(64, activation="relu")(combinedInput)  ## keep neurons in multiples of 4
top_model= Dense(11, activation="softmax")(top)
#combinedInput = concatenate([mlp.output, cnn.output])
#model = Model(inputs=[mlp.input, cnn.input], outputs=top_model)
#top_model= Dense(11, activation="softmax")(combinedInput)
model = Model(inputs=[mlp.input, cnn.input], outputs=top_model)
#model.summary()
## training ##################################################################################
#model.compile(loss=tf.keras.losses.BinaryCrossentropy(from_logits=True), optimizer=optimizers.Adam(lr=1e-4),metrics=['acc'])
model.compile(loss='categorical_crossentropy', optimizer=optimizers.Adam(lr=1e-4),metrics=['acc'])

history= model.fit(x=[tr_rough_X_tensor, train_data], y=tr_rough_Y_tensor, validation_data=([ts_rough_X_tensor, val], 
                   ts_rough_Y_tensor), epochs=100, batch_size=32)
(eval_loss, eval_accuracy) = model.evaluate([ts_rough_X_tensor, val], ts_rough_Y_tensor, batch_size=batch_size, verbose=1)

print("test accuracy: {:.2f}%".format(eval_accuracy * 100)) 
print("test Loss: {}".format(eval_loss)) 
model.save('fusion_model_densenet121_seq.h5')
# Out:
# Epoch 1/100
# 7/7 [==============================] - 0s 68ms/step - loss: 2.8781 - acc: 0.1364 - val_loss: 2.9003 - val_acc: 0.0909
# Epoch 2/100
# 7/7 [==============================] - 0s 40ms/step - loss: 2.7007 - acc: 0.1318 - val_loss: 2.6325 - val_acc: 0.1455
# Epoch 3/100
# 7/7 [==============================] - 0s 39ms/step - loss: 2.3907 - acc: 0.1955 - val_loss: 2.4178 - val_acc: 0.2364
# Epoch 4/100
# 7/7 [==============================] - 0s 43ms/step - loss: 2.1744 - acc: 0.2636 - val_loss: 2.3092 - val_acc: 0.2364
# Epoch 5/100
# 7/7 [==============================] - 0s 39ms/step - loss: 2.0470 - acc: 0.2500 - val_loss: 2.2749 - val_acc: 0.2364
# Epoch 6/100
# 7/7 [==============================] - 0s 41ms/step - loss: 1.8262 - acc: 0.3727 - val_loss: 2.1971 - val_acc: 0.2364
# Epoch 7/100
# 7/7 [==============================] - 0s 38ms/step - loss: 1.7208 - acc: 0.3909 - val_loss: 2.1149 - val_acc: 0.2727
# Epoch 8/100
# 7/7 [==============================] - 0s 38ms/step - loss: 1.5713 - acc: 0.5000 - val_loss: 2.0128 - val_acc: 0.2909
# Epoch 9/100
# 7/7 [==============================] - 0s 39ms/step - loss: 1.5675 - acc: 0.4545 - val_loss: 1.9310 - val_acc: 0.4000
# Epoch 10/100
# 7/7 [==============================] - 0s 41ms/step - loss: 1.4738 - acc: 0.5136 - val_loss: 1.8787 - val_acc: 0.4364
# Epoch 11/100
# 7/7 [==============================] - 0s 39ms/step - loss: 1.3325 - acc: 0.5955 - val_loss: 1.7955 - val_acc: 0.4727
# Epoch 12/100
# 7/7 [==============================] - 0s 39ms/step - loss: 1.2792 - acc: 0.5909 - val_loss: 1.7092 - val_acc: 0.4909
# Epoch 13/100
# 7/7 [==============================] - 0s 40ms/step - loss: 1.2437 - acc: 0.6455 - val_loss: 1.6559 - val_acc: 0.5091
# Epoch 14/100
# 7/7 [==============================] - 0s 40ms/step - loss: 1.1422 - acc: 0.6591 - val_loss: 1.6409 - val_acc: 0.5455
# Epoch 15/100
# 7/7 [==============================] - 0s 39ms/step - loss: 1.1547 - acc: 0.6682 - val_loss: 1.6328 - val_acc: 0.5091
# Epoch 16/100
# 7/7 [==============================] - 0s 38ms/step - loss: 1.1061 - acc: 0.7000 - val_loss: 1.5864 - val_acc: 0.5636
# Epoch 17/100
# 7/7 [==============================] - 0s 42ms/step - loss: 1.0528 - acc: 0.7136 - val_loss: 1.5159 - val_acc: 0.5818
# Epoch 18/100
# 7/7 [==============================] - 0s 39ms/step - loss: 1.0073 - acc: 0.7455 - val_loss: 1.4226 - val_acc: 0.6182
# Epoch 19/100
# 7/7 [==============================] - 0s 39ms/step - loss: 0.9728 - acc: 0.7636 - val_loss: 1.3511 - val_acc: 0.6364
# Epoch 20/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.9267 - acc: 0.7591 - val_loss: 1.2756 - val_acc: 0.6545
# Epoch 21/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.9043 - acc: 0.7773 - val_loss: 1.2283 - val_acc: 0.6545
# Epoch 22/100
# 7/7 [==============================] - 0s 39ms/step - loss: 0.9206 - acc: 0.7955 - val_loss: 1.2088 - val_acc: 0.6545
# Epoch 23/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.8877 - acc: 0.8000 - val_loss: 1.1876 - val_acc: 0.6727
# Epoch 24/100
# 7/7 [==============================] - 0s 39ms/step - loss: 0.7930 - acc: 0.8318 - val_loss: 1.1849 - val_acc: 0.6909
# Epoch 25/100
# 7/7 [==============================] - 0s 39ms/step - loss: 0.7833 - acc: 0.8500 - val_loss: 1.1728 - val_acc: 0.7455
# Epoch 26/100
# 7/7 [==============================] - 0s 39ms/step - loss: 0.8059 - acc: 0.8136 - val_loss: 1.1227 - val_acc: 0.7455
# Epoch 27/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.7239 - acc: 0.8727 - val_loss: 1.0759 - val_acc: 0.7636
# Epoch 28/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.7073 - acc: 0.8818 - val_loss: 1.0387 - val_acc: 0.7455
# Epoch 29/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.6493 - acc: 0.9000 - val_loss: 1.0155 - val_acc: 0.8000
# Epoch 30/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.6972 - acc: 0.8364 - val_loss: 0.9706 - val_acc: 0.8182
# Epoch 31/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.6351 - acc: 0.8955 - val_loss: 0.9372 - val_acc: 0.8000
# Epoch 32/100
# 7/7 [==============================] - 0s 39ms/step - loss: 0.6038 - acc: 0.9045 - val_loss: 0.9158 - val_acc: 0.8364
# Epoch 33/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.6299 - acc: 0.9000 - val_loss: 0.9070 - val_acc: 0.8000
# Epoch 34/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.6353 - acc: 0.9000 - val_loss: 0.8937 - val_acc: 0.8364
# Epoch 35/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.5866 - acc: 0.9136 - val_loss: 0.8842 - val_acc: 0.8364
# Epoch 36/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.5401 - acc: 0.9364 - val_loss: 0.8609 - val_acc: 0.8182
# Epoch 37/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.5305 - acc: 0.9318 - val_loss: 0.8422 - val_acc: 0.8364
# Epoch 38/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.5018 - acc: 0.9500 - val_loss: 0.8214 - val_acc: 0.8364
# Epoch 39/100
# 7/7 [==============================] - 0s 39ms/step - loss: 0.5386 - acc: 0.9273 - val_loss: 0.8023 - val_acc: 0.8364
# Epoch 40/100
# 7/7 [==============================] - 0s 39ms/step - loss: 0.5113 - acc: 0.9045 - val_loss: 0.7871 - val_acc: 0.8727
# Epoch 41/100
# 7/7 [==============================] - 0s 43ms/step - loss: 0.4974 - acc: 0.9364 - val_loss: 0.7687 - val_acc: 0.8909
# Epoch 42/100
# 7/7 [==============================] - 0s 41ms/step - loss: 0.4864 - acc: 0.9136 - val_loss: 0.7503 - val_acc: 0.8909
# Epoch 43/100
# 7/7 [==============================] - 0s 40ms/step - loss: 0.4431 - acc: 0.9500 - val_loss: 0.7281 - val_acc: 0.8727
# Epoch 44/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.4443 - acc: 0.9409 - val_loss: 0.7143 - val_acc: 0.8727
# Epoch 45/100
# 7/7 [==============================] - 0s 43ms/step - loss: 0.5052 - acc: 0.9409 - val_loss: 0.7134 - val_acc: 0.8545
# Epoch 46/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.4525 - acc: 0.9682 - val_loss: 0.7147 - val_acc: 0.8545
# Epoch 47/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.4190 - acc: 0.9364 - val_loss: 0.7073 - val_acc: 0.8545
# Epoch 48/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.4269 - acc: 0.9682 - val_loss: 0.6867 - val_acc: 0.8727
# Epoch 49/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.4091 - acc: 0.9636 - val_loss: 0.6670 - val_acc: 0.8727
# Epoch 50/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.3703 - acc: 0.9773 - val_loss: 0.6455 - val_acc: 0.8727
# Epoch 51/100
# 7/7 [==============================] - 0s 39ms/step - loss: 0.3968 - acc: 0.9682 - val_loss: 0.6272 - val_acc: 0.8727
# Epoch 52/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.3952 - acc: 0.9682 - val_loss: 0.6225 - val_acc: 0.8727
# Epoch 53/100
# 7/7 [==============================] - 0s 41ms/step - loss: 0.3960 - acc: 0.9682 - val_loss: 0.6192 - val_acc: 0.8545
# Epoch 54/100
# 7/7 [==============================] - 0s 39ms/step - loss: 0.3420 - acc: 0.9682 - val_loss: 0.6185 - val_acc: 0.8545
# Epoch 55/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.3570 - acc: 0.9591 - val_loss: 0.6170 - val_acc: 0.8727
# Epoch 56/100
# 7/7 [==============================] - 0s 36ms/step - loss: 0.3407 - acc: 0.9727 - val_loss: 0.6026 - val_acc: 0.8727
# Epoch 57/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.3199 - acc: 0.9591 - val_loss: 0.5942 - val_acc: 0.8727
# Epoch 58/100
# 7/7 [==============================] - 0s 41ms/step - loss: 0.3425 - acc: 0.9818 - val_loss: 0.5850 - val_acc: 0.8545
# Epoch 59/100
# 7/7 [==============================] - 0s 40ms/step - loss: 0.3379 - acc: 0.9864 - val_loss: 0.5770 - val_acc: 0.8545
# Epoch 60/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.2825 - acc: 0.9818 - val_loss: 0.5650 - val_acc: 0.8545
# Epoch 61/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.3066 - acc: 0.9773 - val_loss: 0.5493 - val_acc: 0.8909
# Epoch 62/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.3213 - acc: 0.9636 - val_loss: 0.5341 - val_acc: 0.8909
# Epoch 63/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.2859 - acc: 0.9864 - val_loss: 0.5325 - val_acc: 0.9091
# Epoch 64/100
# 7/7 [==============================] - 0s 41ms/step - loss: 0.3060 - acc: 0.9636 - val_loss: 0.5343 - val_acc: 0.9091
# Epoch 65/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.2810 - acc: 0.9773 - val_loss: 0.5319 - val_acc: 0.9091
# Epoch 66/100
# 7/7 [==============================] - 0s 36ms/step - loss: 0.2708 - acc: 0.9909 - val_loss: 0.5292 - val_acc: 0.9091
# Epoch 67/100
# 7/7 [==============================] - 0s 40ms/step - loss: 0.2513 - acc: 0.9909 - val_loss: 0.5322 - val_acc: 0.9091
# Epoch 68/100
# 7/7 [==============================] - 0s 39ms/step - loss: 0.2844 - acc: 0.9773 - val_loss: 0.5325 - val_acc: 0.8909
# Epoch 69/100
# 7/7 [==============================] - 0s 39ms/step - loss: 0.2163 - acc: 0.9909 - val_loss: 0.5264 - val_acc: 0.8909
# Epoch 70/100
# 7/7 [==============================] - 0s 39ms/step - loss: 0.2401 - acc: 0.9864 - val_loss: 0.5247 - val_acc: 0.8909
# Epoch 71/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.2460 - acc: 0.9682 - val_loss: 0.5221 - val_acc: 0.9091
# Epoch 72/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.2508 - acc: 0.9818 - val_loss: 0.5149 - val_acc: 0.9091
# Epoch 73/100
# 7/7 [==============================] - 0s 39ms/step - loss: 0.2321 - acc: 0.9955 - val_loss: 0.5080 - val_acc: 0.9091
# Epoch 74/100
# 7/7 [==============================] - 0s 41ms/step - loss: 0.2428 - acc: 0.9864 - val_loss: 0.5043 - val_acc: 0.9091
# Epoch 75/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.2471 - acc: 0.9727 - val_loss: 0.4965 - val_acc: 0.9091
# Epoch 76/100
# 7/7 [==============================] - 0s 41ms/step - loss: 0.2101 - acc: 0.9909 - val_loss: 0.4882 - val_acc: 0.9091
# Epoch 77/100
# 7/7 [==============================] - 0s 39ms/step - loss: 0.2202 - acc: 0.9955 - val_loss: 0.4857 - val_acc: 0.9091
# Epoch 78/100
# 7/7 [==============================] - 0s 41ms/step - loss: 0.2117 - acc: 0.9864 - val_loss: 0.4815 - val_acc: 0.9091
# Epoch 79/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.2327 - acc: 0.9818 - val_loss: 0.4746 - val_acc: 0.8909
# Epoch 80/100
# 7/7 [==============================] - 0s 40ms/step - loss: 0.2201 - acc: 0.9773 - val_loss: 0.4701 - val_acc: 0.8909
# Epoch 81/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.2075 - acc: 0.9909 - val_loss: 0.4625 - val_acc: 0.9091
# Epoch 82/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.1968 - acc: 0.9909 - val_loss: 0.4580 - val_acc: 0.9091
# Epoch 83/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.1852 - acc: 0.9864 - val_loss: 0.4585 - val_acc: 0.9091
# Epoch 84/100
# 7/7 [==============================] - 0s 39ms/step - loss: 0.2228 - acc: 0.9864 - val_loss: 0.4678 - val_acc: 0.9091
# Epoch 85/100
# 7/7 [==============================] - 0s 39ms/step - loss: 0.2217 - acc: 0.9864 - val_loss: 0.4709 - val_acc: 0.8909
# Epoch 86/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.2119 - acc: 0.9909 - val_loss: 0.4615 - val_acc: 0.9091
# Epoch 87/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.1830 - acc: 1.0000 - val_loss: 0.4486 - val_acc: 0.9091
# Epoch 88/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.1694 - acc: 0.9909 - val_loss: 0.4424 - val_acc: 0.9091
# Epoch 89/100
# 7/7 [==============================] - 0s 39ms/step - loss: 0.2058 - acc: 0.9773 - val_loss: 0.4336 - val_acc: 0.9091
# Epoch 90/100
# 7/7 [==============================] - 0s 39ms/step - loss: 0.1908 - acc: 0.9773 - val_loss: 0.4341 - val_acc: 0.9091
# Epoch 91/100
# 7/7 [==============================] - 0s 39ms/step - loss: 0.1573 - acc: 0.9864 - val_loss: 0.4382 - val_acc: 0.9091
# Epoch 92/100
# 7/7 [==============================] - 0s 40ms/step - loss: 0.1730 - acc: 0.9909 - val_loss: 0.4395 - val_acc: 0.9091
# Epoch 93/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.1634 - acc: 0.9955 - val_loss: 0.4381 - val_acc: 0.9091
# Epoch 94/100
# 7/7 [==============================] - 0s 40ms/step - loss: 0.1606 - acc: 0.9909 - val_loss: 0.4348 - val_acc: 0.8909
# Epoch 95/100
# 7/7 [==============================] - 0s 40ms/step - loss: 0.1637 - acc: 0.9909 - val_loss: 0.4313 - val_acc: 0.8909
# Epoch 96/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.1537 - acc: 0.9955 - val_loss: 0.4246 - val_acc: 0.8909
# Epoch 97/100
# 7/7 [==============================] - 0s 42ms/step - loss: 0.1716 - acc: 0.9864 - val_loss: 0.4155 - val_acc: 0.8909
# Epoch 98/100
# 7/7 [==============================] - 0s 45ms/step - loss: 0.1590 - acc: 0.9864 - val_loss: 0.4083 - val_acc: 0.8727
# Epoch 99/100
# 7/7 [==============================] - 0s 40ms/step - loss: 0.1420 - acc: 1.0000 - val_loss: 0.4086 - val_acc: 0.8727
# Epoch 100/100
# 7/7 [==============================] - 0s 41ms/step - loss: 0.1355 - acc: 1.0000 - val_loss: 0.4087 - val_acc: 0.8727
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4087 - acc: 0.8727
# test accuracy: 87.27%
# test Loss: 0.40866976976394653

# %%
##### ACCURACY ######################
ax = plt.axes()
acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(len(acc))
plt.plot(epochs, acc, 'r', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Test acc')
plt.title('Training and Test Accuracy',fontsize=20)
plt.ylabel('Accuracy',fontsize=20) 
plt.xlabel('Epoch',fontsize=20)
plt.legend()
plt.tick_params(axis='both', labelsize=12)
plt.savefig("fusion_densenet121_ACCgraph.pdf",bbox_inches='tight')
plt.savefig("fusion_densenet121_ACCgraph.eps",bbox_inches='tight')

###### LOSS ################################
plt.figure()
plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Test loss')
plt.title('Training and Test Loss',fontsize=20)
plt.ylabel('Loss',fontsize=20) 
plt.xlabel('Epoch',fontsize=20)
plt.legend()
plt.tick_params(axis='both', labelsize=12)
plt.savefig("fusion_Densenet121_loss.pdf",bbox_inches='tight')
plt.savefig("fusion_Densenet121_loss.eps",bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
y_pred=model.predict([ts_rough_X_tensor, val]) 
y_pred=np.argmax(y_pred, axis=1)
y_test=np.argmax(ts_rough_Y_tensor, axis=1)
cm = confusion_matrix(y_test, y_pred)
#print(cm)
import seaborn as sns; sns.set_theme()
sn.set(font_scale=2)
graph=plt.figure(figsize = (10,10))
classes=['ABS','PA','PC','PP','WOOD1','WOOD2','WOOD3','WOOD4','WOOD5','WOOD6','WOOD7']
ax = sn.heatmap(cm, cmap="Blues", annot=True, xticklabels=classes, yticklabels=classes, cbar=True)
ax.set(title='Confusion Matrix', xlabel="Predicted labels", ylabel="True labels")
plt.xticks(rotation=45)
plt.tick_params(axis='both', labelsize=18)
plt.show()
graph.savefig("fusion_densenet121_confusion_matrix.pdf",bbox_inches='tight')###################
graph.savefig("fusion_densenet121_confusion_matrix.eps",bbox_inches='tight')
####### generate classification report ###############################################################
report=classification_report(y_test, y_pred)
print(report)
report_df = pd.DataFrame([report])
print(report_df.to_csv('fusion_densenet121_report.csv'))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         6
#            1       1.00      1.00      1.00         3
#            2       1.00      1.00      1.00         6
#            3       1.00      1.00      1.00         5
#            4       1.00      1.00      1.00         7
#            5       1.00      1.00      1.00         3
#            6       1.00      1.00      1.00         6
#            7       1.00      1.00      1.00         5
#            8       1.00      1.00      1.00         4
#            9       1.00      1.00      1.00         6
#           10       1.00      1.00      1.00         4
#
#     accuracy                           1.00        55
#    macro avg       1.00      1.00      1.00        55
# weighted avg       1.00      1.00      1.00        55
#
# None
